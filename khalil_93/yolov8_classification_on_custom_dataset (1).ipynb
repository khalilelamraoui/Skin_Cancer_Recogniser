# %% [markdown]
# # Train YOLOv8 Classification on Your Custom Dataset
#
#
# ## Steps
#
# In this noteboook, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
# - Export Model
# - Download Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Runtime` -> `Change Runtime Type`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sat May 10 21:43:34 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 572.83                 Driver Version: 572.83         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   55C    P8             10W /   75W |    1094MiB /   4096MiB |     38%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2876    C+G   ...64__zpdnekdrzrea0\Spotify.exe      N/A      |
# |    0   N/A  N/A            3364    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A            5500    C+G   ....0.3240.50\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            5872    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           12256    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           15756    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           15796    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           16064    C+G   ...SnippingTool\SnippingTool.exe      N/A      |
# |    0   N/A  N/A           16120    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           17012    C+G   ...4__cv1g1gvanyjgm\WhatsApp.exe      N/A      |
# |    0   N/A  N/A           17432    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           18784    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A           18900    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           19228    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           20092    C+G   ....0.3240.64\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           24436    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A           25088    C+G   ...cord\app-1.0.9191\Discord.exe      N/A      |
# |    0   N/A  N/A           25636    C+G   ...indows\System32\ShellHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\khalil_93

# %% [markdown]
# ## Install YOLOv8
# There are two ways to install YOLOv8
# - From the source (for development)
# - Via pip (recommended)

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.122  Python-3.11.2 torch-2.7.0+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# Setup complete  (12 CPUs, 15.4 GB RAM, 418.3/476.0 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="v9TzUXnGAA3HERPeyXBE")
project = rf.workspace("bigdata-xv5t7").project("skin-9nkfv")
version = project.version(1)
dataset = version.download("folder")
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\khali\\OneDrive\\Desktop\\AI\\venv\\Lib\\site-packages\\cv2\\cv2.pyd'
# Check the permissions.
# Collecting roboflow
#   Using cached roboflow-1.1.63-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (2025.4.26)
# Collecting idna==3.7 (from roboflow)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (3.10.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (2.2.5)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (11.2.1)
# Requirement already satisfied: pillow-heif>=0.18.0 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (0.22.0)
# Requirement already satisfied: python-dateutil in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: requests in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filetype in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from matplotlib->roboflow) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khali\onedrive\desktop\ai\venv\lib\site-packages (from requests->roboflow) (3.4.1)
# Using cached roboflow-1.1.63-py3-none-any.whl (85 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: opencv-python-headless, idna, requests-toolbelt, roboflow
#
#    ---------------------------------------- 0/4 [opencv-python-headless]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 get_ipython().system('pip install roboflow')
# ----> 3 from roboflow import Roboflow
#       4 rf = Roboflow(api_key="v9TzUXnGAA3HERPeyXBE")
#       5 project = rf.workspace("bigdata-xv5t7").project("skin-9nkfv")
#
# ModuleNotFoundError: No module named 'roboflow'

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -e .

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## Preparing a custom dataset
#
# To prepare the custom data for classification using YOLO v8, Ensure that your dataset is structured as described below: You should have separate folders for train, test, and val, each containing subfolders for each class (e.g., ClassA, ClassB). Place the corresponding images for each class within their respective subfolders.

# %% [markdown]
# ### Dataset Structure
# ```
# Dataset
# │
# └───train
# │   └───ClassA
# │       │   ClassA_1.jpg
# │       │   ClassA_2.jpg
# │       │   ...
# │   └───ClassB
# │       │   ClassB_1.jpg
# │       │   ClassB_2.jpg
# │       │   ...
# │   └───...
# └───test
# │   └───ClassA
# │       │   ClassA_9090.jpg
# │       │   ClassA_9895.jpg
# │       │   ...
# │   └───ClassB
# │       │   ClassB_2343.jpg
# │       │   ClassB_2312.jpg
# │       │   ...
# │   └───...
# └───val
# │   └───ClassA
# │       │   ClassA_3070.jpg
# │       │   ClassA_2845.jpg
# │       │   ...
# │   └───ClassB
# │       │   ClassB_2903.jpg
# │       │   ClassB_2232.jpg
# │       │   ...
# │   └───...
# ```

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=classify mode=train model=yolov8m-cls.pt data='skin-1' epochs=50 imgsz=640
# Out:
# c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\khalil_93
# ^C
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m-cls.pt to 'yolov8m-cls.pt'...
# New https://pypi.org/project/ultralytics/8.3.132 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.122  Python-3.11.2 torch-2.7.0+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# engine\trainer: task=classify, mode=train, model=yolov8m-cls.pt, data=skin-1, epochs=50, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, cutmix=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=runs\classify\train
#
# WARNING Dataset not found, missing path C:\Users\khali\OneDrive\Desktop\Skin Cancer Recogniser.v2i.yolov8\datasets\skin-1, attempting download...
# Downloading https://ultralytics.com/assets/skin-1.zip to 'C:\Users\khali\OneDrive\Desktop\Skin Cancer Recogniser.v2i.yolov8\datasets\skin-1.zip'...
# WARNING Download failure, retrying 1/3 https://ultralytics.com/assets/skin-1.zip...
# Dataset download success  (4.5s), saved to C:\Users\khali\OneDrive\Desktop\Skin Cancer Recogniser.v2i.yolov8\datasets\skin-1
#
# WARNING Dataset 'split=train' not found at C:\Users\khali\OneDrive\Desktop\Skin Cancer Recogniser.v2i.yolov8\datasets\skin-1\train
# ERROR No images found in C:\Users\khali\OneDrive\Desktop\Skin Cancer Recogniser.v2i.yolov8\datasets\skin-1 or its subdirectories.
#   0%|          | 0.00/32.7M [00:00<?, ?B/s]
#   0%|          | 128k/32.7M [00:34<2:28:59, 3.82kB/s]
#   1%|          | 256k/32.7M [00:35<1:04:40, 8.77kB/s]
#   1%|          | 384k/32.7M [00:37<38:53, 14.5kB/s]
#   2%|▏         | 512k/32.7M [00:40<28:24, 19.8kB/s]
#   2%|▏         | 640k/32.7M [00:42<21:24, 26.2kB/s]
#   2%|▏         | 768k/32.7M [00:46<20:00, 27.9kB/s]
#   3%|▎         | 896k/32.7M [00:49<16:43, 33.2kB/s]
#   3%|▎         | 1.00M/32.7M [00:50<13:03, 42.4kB/s]
#   3%|▎         | 1.12M/32.7M [00:52<11:34, 47.7kB/s]
#   4%|▍         | 1.25M/32.7M [00:53<09:35, 57.3kB/s]
#   4%|▍         | 1.38M/32.7M [00:54<07:47, 70.2kB/s]
#   5%|▍         | 1.50M/32.7M [00:55<06:31, 83.6kB/s]
#   5%|▍         | 1.62M/32.7M [00:56<05:27, 99.6kB/s]
#   5%|▌         | 1.75M/32.7M [00:57<05:06, 106kB/s]
#   6%|▌         | 1.88M/32.7M [00:59<06:09, 87.4kB/s]
#   6%|▌         | 2.00M/32.7M [01:00<06:02, 88.8kB/s]
#   6%|▋         | 2.12M/32.7M [01:02<06:38, 80.4kB/s]
#   7%|▋         | 2.25M/32.7M [01:04<06:15, 85.0kB/s]
#   7%|▋         | 2.38M/32.7M [01:06<06:46, 78.2kB/s]
#   8%|▊         | 2.50M/32.7M [01:09<09:06, 57.9kB/s]
#   8%|▊         | 2.62M/32.7M [01:13<11:12, 46.9kB/s]
#   8%|▊         | 2.75M/32.7M [01:20<15:40, 33.4kB/s]
#   9%|▉         | 2.88M/32.7M [01:22<13:38, 38.2kB/s]
#   9%|▉         | 3.00M/32.7M [01:25<13:24, 38.7kB/s]
#  10%|▉         | 3.12M/32.7M [01:29<12:55, 40.0kB/s]
#  10%|▉         | 3.25M/32.7M [01:29<09:28, 54.3kB/s]
#  10%|█         | 3.38M/32.7M [01:30<07:20, 69.8kB/s]
#  11%|█         | 3.50M/32.7M [01:30<05:24, 94.4kB/s]
#  11%|█         | 3.62M/32.7M [01:30<04:05, 124kB/s]
#  11%|█▏        | 3.75M/32.7M [01:30<03:03, 166kB/s]
#  94%|█████████▍| 30.9M/32.7M [03:32<00:11, 171kB/s]
#  95%|█████████▍| 31.0M/32.7M [03:33<00:10, 170kB/s]
#  95%|█████████▌| 31.1M/32.7M [03:34<00:10, 161kB/s]
#  96%|█████████▌| 31.2M/32.7M [03:35<00:12, 122kB/s]
#  96%|█████████▌| 31.4M/32.7M [03:36<00:10, 137kB/s]
#  96%|█████████▋| 31.5M/32.7M [03:38<00:10, 114kB/s]
#  97%|█████████▋| 31.6M/32.7M [03:41<00:15, 73.4kB/s]
#  97%|█████████▋| 31.8M/32.7M [03:42<00:11, 86.2kB/s]
#  97%|█████████▋| 31.9M/32.7M [03:42<00:07, 116kB/s]
#  98%|█████████▊| 32.0M/32.7M [03:44<00:06, 108kB/s]
#  98%|█████████▊| 32.1M/32.7M [03:44<00:05, 117kB/s]
#  99%|█████████▊| 32.2M/32.7M [03:45<00:03, 134kB/s]
#  99%|█████████▉| 32.4M/32.7M [03:45<00:02, 166kB/s]
#  99%|█████████▉| 32.5M/32.7M [03:46<00:00, 214kB/s]
# 100%|█████████▉| 32.6M/32.7M [03:46<00:00, 256kB/s]
# 100%|██████████| 32.7M/32.7M [03:46<00:00, 275kB/s]
# 100%|██████████| 32.7M/32.7M [03:46<00:00, 151kB/s]
#
# #=#=#
# ##O#-#
# ##O=#  #
# #=#=-#  #
# ######################################################################## 100.0%
# Traceback (most recent call last):
#   File "C:\Users\khali\OneDrive\Desktop\AI\venv\Lib\site-packages\ultralytics\engine\trainer.py", line 574, in get_dataset
#     data = check_cls_dataset(self.args.data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\khali\OneDrive\Desktop\AI\venv\Lib\site-packages\ultralytics\data\utils.py", line 540, in check_cls_dataset
#     names = [x.name for x in (data_dir / "train").iterdir() if x.is_dir()]  # class names list
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\khali\OneDrive\Desktop\AI\venv\Lib\site-packages\ultralytics\data\utils.py", line 540, in <listcomp>
#     names = [x.name for x in (data_dir / "train").iterdir() if x.is_dir()]  # class names list
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\pathlib.py", line 931, in iterdir
#     for name in os.listdir(self):
#                 ^^^^^^^^^^^^^^^^
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\khali\\OneDrive\\Desktop\\Skin Cancer Recogniser.v2i.yolov8\\datasets\\skin-1\\train'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\khali\OneDrive\Desktop\AI\venv\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\khali\OneDrive\Desktop\AI\venv\Lib\site-packages\ultralytics\cfg\__init__.py", line 988, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\khali\OneDrive\Desktop\AI\venv\Lib\site-packages\ultralytics\engine\model.py", line 784, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\khali\OneDrive\Desktop\AI\venv\Lib\site-packages\ultralytics\models\yolo\classify\train.py", line 73, in __init__
#     super().__init__(cfg, overrides, _callbacks)
#   File "C:\Users\khali\OneDrive\Desktop\AI\venv\Lib\site-packages\ultralytics\engine\trainer.py", line 137, in __init__
#     self.trainset, self.testset = self.get_dataset()
#                                   ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\khali\OneDrive\Desktop\AI\venv\Lib\site-packages\ultralytics\engine\trainer.py", line 585, in get_dataset
#     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
# RuntimeError: Dataset 'skin-1' error  [WinError 3] The system cannot find the path specified: 'C:\\Users\\khali\\OneDrive\\Desktop\\Skin Cancer Recogniser.v2i.yolov8\\datasets\\skin-1\\train'

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=classify mode=val model={HOME}/khalil_93/best.pt data='skin-1'
# Out:
# c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser
# Ultralytics 8.3.122  Python-3.11.2 torch-2.7.0+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# YOLOv8m-cls summary (fused): 42 layers, 15,767,780 parameters, 0 gradients, 41.6 GFLOPs
# WARNING Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\train... found 9053 images in 4 classes
# val: C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... found 1293 images in 4 classes
# test: C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... found 1293 images in 4 classes
# val: Fast image access  (ping: 0.10.0 ms, read: 262.1103.4 MB/s, size: 33.4 KB)
# val: New cache created: C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test.cache
#                    all      0.933          1
# Speed: 0.0ms preprocess, 282.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\val
#  Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test...:   0%|          | 0/1293 [00:00<?, ?it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 54 images, 0 corrupt:   4%|▍         | 54/1293 [00:00<00:02, 528.40it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 118 images, 0 corrupt:   9%|▉         | 118/1293 [00:00<00:02, 558.66it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 182 images, 0 corrupt:  14%|█▍        | 182/1293 [00:00<00:01, 571.21it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 246 images, 0 corrupt:  19%|█▉        | 246/1293 [00:00<00:01, 576.56it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 304 images, 0 corrupt:  24%|██▎       | 304/1293 [00:00<00:01, 570.61it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 362 images, 0 corrupt:  28%|██▊       | 362/1293 [00:00<00:01, 564.64it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 436 images, 0 corrupt:  34%|███▎      | 436/1293 [00:00<00:01, 609.52it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 497 images, 0 corrupt:  38%|███▊      | 497/1293 [00:00<00:01, 605.22it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 558 images, 0 corrupt:  43%|████▎     | 558/1293 [00:00<00:01, 590.42it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 633 images, 0 corrupt:  49%|████▉     | 633/1293 [00:01<00:01, 622.85it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 697 images, 0 corrupt:  54%|█████▍    | 697/1293 [00:01<00:00, 613.60it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 761 images, 0 corrupt:  59%|█████▉    | 761/1293 [00:01<00:00, 602.40it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 822 images, 0 corrupt:  64%|██████▎   | 822/1293 [00:01<00:00, 601.92it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 883 images, 0 corrupt:  68%|██████▊   | 883/1293 [00:01<00:00, 590.01it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 968 images, 0 corrupt:  75%|███████▍  | 968/1293 [00:01<00:00, 664.15it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 1035 images, 0 corrupt:  80%|████████  | 1035/1293 [00:01<00:00, 651.49it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 1101 images, 0 corrupt:  85%|████████▌ | 1101/1293 [00:01<00:00, 641.68it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 1166 images, 0 corrupt:  90%|█████████ | 1166/1293 [00:01<00:00, 631.84it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 1230 images, 0 corrupt:  95%|█████████▌| 1230/1293 [00:02<00:00, 620.06it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 1293 images, 0 corrupt: 100%|██████████| 1293/1293 [00:02<00:00, 595.95it/s]
# val: Scanning C:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test... 1293 images, 0 corrupt: 100%|██████████| 1293/1293 [00:02<00:00, 604.61it/s]
# C:\Users\khali\OneDrive\Desktop\AI\venv\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#
#                classes   top1_acc   top5_acc:   0%|          | 0/81 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   1%|          | 1/81 [00:05<06:40,  5.00s/it]
#                classes   top1_acc   top5_acc:   2%|▏         | 2/81 [00:10<06:54,  5.25s/it]
#                classes   top1_acc   top5_acc:   4%|▎         | 3/81 [00:15<06:35,  5.07s/it]
#                classes   top1_acc   top5_acc:   5%|▍         | 4/81 [00:20<06:24,  4.99s/it]
#                classes   top1_acc   top5_acc:   6%|▌         | 5/81 [00:25<06:16,  4.96s/it]
#                classes   top1_acc   top5_acc:   7%|▋         | 6/81 [00:29<05:49,  4.67s/it]
#                classes   top1_acc   top5_acc:   9%|▊         | 7/81 [00:33<05:31,  4.48s/it]
#                classes   top1_acc   top5_acc:  10%|▉         | 8/81 [00:37<05:23,  4.43s/it]
#                classes   top1_acc   top5_acc:  11%|█         | 9/81 [00:42<05:23,  4.50s/it]
#                classes   top1_acc   top5_acc:  12%|█▏        | 10/81 [00:46<05:06,  4.31s/it]
#                classes   top1_acc   top5_acc:  14%|█▎        | 11/81 [00:50<04:53,  4.19s/it]
#                classes   top1_acc   top5_acc:  15%|█▍        | 12/81 [00:54<04:57,  4.31s/it]
#                classes   top1_acc   top5_acc:  16%|█▌        | 13/81 [00:58<04:47,  4.23s/it]
#                classes   top1_acc   top5_acc:  58%|█████▊    | 47/81 [03:27<02:50,  5.01s/it]
#                classes   top1_acc   top5_acc:  59%|█████▉    | 48/81 [03:31<02:34,  4.70s/it]
#                classes   top1_acc   top5_acc:  60%|██████    | 49/81 [03:38<02:50,  5.33s/it]
#                classes   top1_acc   top5_acc:  62%|██████▏   | 50/81 [03:47<03:22,  6.55s/it]
#                classes   top1_acc   top5_acc:  63%|██████▎   | 51/81 [03:55<03:24,  6.81s/it]
#                classes   top1_acc   top5_acc:  64%|██████▍   | 52/81 [04:00<03:03,  6.34s/it]
#                classes   top1_acc   top5_acc:  65%|██████▌   | 53/81 [04:05<02:49,  6.06s/it]
#                classes   top1_acc   top5_acc:  67%|██████▋   | 54/81 [04:10<02:34,  5.72s/it]
#                classes   top1_acc   top5_acc:  68%|██████▊   | 55/81 [04:16<02:28,  5.69s/it]
#                classes   top1_acc   top5_acc:  69%|██████▉   | 56/81 [04:22<02:28,  5.95s/it]
#                classes   top1_acc   top5_acc:  70%|███████   | 57/81 [04:30<02:35,  6.48s/it]
#                classes   top1_acc   top5_acc:  72%|███████▏  | 58/81 [04:36<02:21,  6.16s/it]
#                classes   top1_acc   top5_acc:  73%|███████▎  | 59/81 [04:41<02:07,  5.80s/it]
#                classes   top1_acc   top5_acc:  74%|███████▍  | 60/81 [04:46<01:59,  5.70s/it]
#                classes   top1_acc   top5_acc:  75%|███████▌  | 61/81 [04:52<01:58,  5.92s/it]
#                classes   top1_acc   top5_acc:  77%|███████▋  | 62/81 [04:57<01:46,  5.59s/it]
#                classes   top1_acc   top5_acc:  78%|███████▊  | 63/81 [05:02<01:33,  5.21s/it]
#                classes   top1_acc   top5_acc:  79%|███████▉  | 64/81 [05:09<01:38,  5.78s/it]
#                classes   top1_acc   top5_acc:  80%|████████  | 65/81 [05:13<01:26,  5.42s/it]
#                classes   top1_acc   top5_acc:  81%|████████▏ | 66/81 [05:18<01:19,  5.30s/it]
#                classes   top1_acc   top5_acc:  83%|████████▎ | 67/81 [05:25<01:18,  5.60s/it]
#                classes   top1_acc   top5_acc:  84%|████████▍ | 68/81 [05:29<01:07,  5.21s/it]
#                classes   top1_acc   top5_acc:  85%|████████▌ | 69/81 [05:33<00:57,  4.81s/it]
#                classes   top1_acc   top5_acc:  86%|████████▋ | 70/81 [05:39<00:57,  5.18s/it]
#                classes   top1_acc   top5_acc:  88%|████████▊ | 71/81 [05:46<00:56,  5.69s/it]
#                classes   top1_acc   top5_acc:  89%|████████▉ | 72/81 [05:50<00:46,  5.20s/it]
#                classes   top1_acc   top5_acc:  90%|█████████ | 73/81 [05:54<00:39,  4.96s/it]
#                classes   top1_acc   top5_acc:  91%|█████████▏| 74/81 [05:58<00:32,  4.59s/it]
#                classes   top1_acc   top5_acc:  93%|█████████▎| 75/81 [06:02<00:26,  4.38s/it]
#                classes   top1_acc   top5_acc:  94%|█████████▍| 76/81 [06:06<00:22,  4.41s/it]
#                classes   top1_acc   top5_acc:  95%|█████████▌| 77/81 [06:11<00:18,  4.62s/it]
#                classes   top1_acc   top5_acc:  96%|█████████▋| 78/81 [06:17<00:14,  4.94s/it]
#                classes   top1_acc   top5_acc:  98%|█████████▊| 79/81 [06:22<00:09,  4.85s/it]
#                classes   top1_acc   top5_acc:  99%|█████████▉| 80/81 [06:26<00:04,  4.63s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 81/81 [06:29<00:00,  4.20s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 81/81 [06:29<00:00,  4.81s/it]

# %%
Image(filename=f'{HOME}/runs/classify/val/confusion_matrix.png')

# %% [markdown]
# ## Inference with Custom Model

# %%
from ultralytics import YOLO
import os
from glob import glob
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Load the trained model
model = YOLO(f"{HOME}/khalil_93/best.pt")

# Test directory path
test_dir = os.path.join(HOME, "skin-1", "test")

# Collect all test images
image_paths = glob(f"{test_dir}/**/*.jpg", recursive=True)  # Adjust extension if needed

# Prepare lists for evaluation
true_labels = []
predicted_labels = []

# Get class name to index mapping
class_names = sorted(os.listdir(test_dir))  # class folder names
name_to_index = {name: idx for idx, name in enumerate(class_names)}
index_to_name = {idx: name for name, idx in name_to_index.items()}

# Predict for each image
for img_path in image_paths:
    true_class = os.path.basename(os.path.dirname(img_path))
    true_labels.append(name_to_index[true_class])

    results = model.predict(img_path, verbose=False)
    pred_idx = results[0].probs.top1
    predicted_labels.append(pred_idx)

# Compute accuracy
acc = accuracy_score(true_labels, predicted_labels)
print(f"\n✅ Test Accuracy: {acc * 100:.2f}%\n")

# Print classification report
print("📊 Classification Report:")
print(classification_report(true_labels, predicted_labels, target_names=class_names))

# Plot confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", xticklabels=class_names, yticklabels=class_names, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# ✅ Test Accuracy: 93.35%
#
# 📊 Classification Report:
#                       precision    recall  f1-score   support
#
# Basal Cell Carcinoma       0.94      0.96      0.95       358
#     Benign Keratosis       0.88      0.84      0.86       223
#             Melanoma       0.99      0.94      0.97       362
#                Nevus       0.91      0.95      0.93       350
#
#             accuracy                           0.93      1293
#            macro avg       0.93      0.92      0.93      1293
#         weighted avg       0.93      0.93      0.93      1293

# %%
from ultralytics import YOLO
import os
from glob import glob
from PIL import Image
from IPython.display import display

# Load trained model
model = YOLO(f"{HOME}/khalil_93/best.pt")  # Update if path differs

# Path to your test set
test_dir = os.path.join(HOME, "skin-1", "test")

# Get all image paths
image_paths = glob(f"{test_dir}/**/*.jpg", recursive=True)  # Adjust image extension if needed

# Run predictions
for img_path in image_paths[:10]:  # Remove [:10] to test all
    # True class is the name of the parent folder
    true_class = os.path.basename(os.path.dirname(img_path))
    
    # Predict
    results = model.predict(img_path)
    pred = results[0].probs.top1
    confidence = results[0].probs.top1conf.item()
    predicted_class = model.model.names[pred]

    # Print results
    print(f"Image: {os.path.basename(img_path)}")
    print(f"  True Class:      {true_class}")
    print(f"  Predicted Class: {predicted_class}")
    print(f"  Confidence:      {confidence:.2f}\n")

    # Optionally display image
    display(Image.open(img_path).resize((256, 256)))
# Out:
# image 1/1 c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test\Basal Cell Carcinoma\ISIC_0024431_jpg.rf.5b00ead1de3b83905d9bea25a0b9ed43.jpg: 640x640 Basal Cell Carcinoma 0.69, Nevus 0.31, Benign Keratosis 0.00, Melanoma 0.00, 294.5ms
# Speed: 13.2ms preprocess, 294.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: ISIC_0024431_jpg.rf.5b00ead1de3b83905d9bea25a0b9ed43.jpg
#   True Class:      Basal Cell Carcinoma
#   Predicted Class: Basal Cell Carcinoma
#   Confidence:      0.69
# <PIL.Image.Image image mode=RGB size=256x256>
# image 1/1 c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test\Basal Cell Carcinoma\ISIC_0024829_jpg.rf.77bc695ff82bb3aac540545c661b822d.jpg: 640x640 Basal Cell Carcinoma 1.00, Nevus 0.00, Benign Keratosis 0.00, Melanoma 0.00, 263.4ms
# Speed: 9.8ms preprocess, 263.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: ISIC_0024829_jpg.rf.77bc695ff82bb3aac540545c661b822d.jpg
#   True Class:      Basal Cell Carcinoma
#   Predicted Class: Basal Cell Carcinoma
#   Confidence:      1.00
# <PIL.Image.Image image mode=RGB size=256x256>
# image 1/1 c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test\Basal Cell Carcinoma\ISIC_0024833_jpg.rf.216267194f745fe281ae099c5949b4b6.jpg: 640x640 Basal Cell Carcinoma 1.00, Nevus 0.00, Benign Keratosis 0.00, Melanoma 0.00, 249.6ms
# Speed: 12.8ms preprocess, 249.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: ISIC_0024833_jpg.rf.216267194f745fe281ae099c5949b4b6.jpg
#   True Class:      Basal Cell Carcinoma
#   Predicted Class: Basal Cell Carcinoma
#   Confidence:      1.00
# <PIL.Image.Image image mode=RGB size=256x256>
# image 1/1 c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test\Basal Cell Carcinoma\ISIC_0024848_jpg.rf.13d1e982e63d1a6df8857fa0cece96b4.jpg: 640x640 Basal Cell Carcinoma 1.00, Benign Keratosis 0.00, Nevus 0.00, Melanoma 0.00, 232.6ms
# Speed: 10.2ms preprocess, 232.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: ISIC_0024848_jpg.rf.13d1e982e63d1a6df8857fa0cece96b4.jpg
#   True Class:      Basal Cell Carcinoma
#   Predicted Class: Basal Cell Carcinoma
#   Confidence:      1.00
# <PIL.Image.Image image mode=RGB size=256x256>
# image 1/1 c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test\Basal Cell Carcinoma\ISIC_0025617_jpg.rf.49acd788fd9e0c5913e9fafb88f16396.jpg: 640x640 Nevus 1.00, Basal Cell Carcinoma 0.00, Benign Keratosis 0.00, Melanoma 0.00, 245.7ms
# Speed: 12.9ms preprocess, 245.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: ISIC_0025617_jpg.rf.49acd788fd9e0c5913e9fafb88f16396.jpg
#   True Class:      Basal Cell Carcinoma
#   Predicted Class: Nevus
#   Confidence:      1.00
# <PIL.Image.Image image mode=RGB size=256x256>
# image 1/1 c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test\Basal Cell Carcinoma\ISIC_0025793_jpg.rf.c93d781e0a54d3bf87774f103066517e.jpg: 640x640 Basal Cell Carcinoma 1.00, Nevus 0.00, Benign Keratosis 0.00, Melanoma 0.00, 264.1ms
# Speed: 16.1ms preprocess, 264.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: ISIC_0025793_jpg.rf.c93d781e0a54d3bf87774f103066517e.jpg
#   True Class:      Basal Cell Carcinoma
#   Predicted Class: Basal Cell Carcinoma
#   Confidence:      1.00
# <PIL.Image.Image image mode=RGB size=256x256>
# image 1/1 c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test\Basal Cell Carcinoma\ISIC_0026074_jpg.rf.b726e5ce2b4e4cac91ebf65024210e23.jpg: 640x640 Basal Cell Carcinoma 1.00, Nevus 0.00, Benign Keratosis 0.00, Melanoma 0.00, 323.9ms
# Speed: 12.1ms preprocess, 323.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: ISIC_0026074_jpg.rf.b726e5ce2b4e4cac91ebf65024210e23.jpg
#   True Class:      Basal Cell Carcinoma
#   Predicted Class: Basal Cell Carcinoma
#   Confidence:      1.00
# <PIL.Image.Image image mode=RGB size=256x256>
# image 1/1 c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test\Basal Cell Carcinoma\ISIC_0026192_jpg.rf.746cfff510bf8678a4fccbe502108076.jpg: 640x640 Basal Cell Carcinoma 1.00, Benign Keratosis 0.00, Nevus 0.00, Melanoma 0.00, 236.6ms
# Speed: 11.1ms preprocess, 236.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: ISIC_0026192_jpg.rf.746cfff510bf8678a4fccbe502108076.jpg
#   True Class:      Basal Cell Carcinoma
#   Predicted Class: Basal Cell Carcinoma
#   Confidence:      1.00
# <PIL.Image.Image image mode=RGB size=256x256>
# image 1/1 c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test\Basal Cell Carcinoma\ISIC_0027004_jpg.rf.6e6a99064952a9d4c852200915c50dea.jpg: 640x640 Basal Cell Carcinoma 1.00, Benign Keratosis 0.00, Nevus 0.00, Melanoma 0.00, 234.5ms
# Speed: 11.7ms preprocess, 234.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: ISIC_0027004_jpg.rf.6e6a99064952a9d4c852200915c50dea.jpg
#   True Class:      Basal Cell Carcinoma
#   Predicted Class: Basal Cell Carcinoma
#   Confidence:      1.00
# <PIL.Image.Image image mode=RGB size=256x256>
# image 1/1 c:\Users\khali\OneDrive\Desktop\AI\Skin_Cancer_Recogniser\skin-1\test\Basal Cell Carcinoma\ISIC_0027281_jpg.rf.96acb423d448e2e94d255d2fb7893b5c.jpg: 640x640 Basal Cell Carcinoma 0.88, Benign Keratosis 0.10, Nevus 0.02, Melanoma 0.00, 227.0ms
# Speed: 11.4ms preprocess, 227.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: ISIC_0027281_jpg.rf.96acb423d448e2e94d255d2fb7893b5c.jpg
#   True Class:      Basal Cell Carcinoma
#   Predicted Class: Basal Cell Carcinoma
#   Confidence:      0.88
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# ## Export Model
#
# Export a YOLOv8 model to any supported format below with the `format` argument, i.e. `format=onnx`. See [YOLOv8 Export Docs](https://docs.ultralytics.com/modes/export/) for more information.
#
# - 💡 ProTip: Export to [ONNX](https://onnx.ai/) or [OpenVINO](https://docs.openvino.ai/latest/index.html) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://developer.nvidia.com/tensorrt) for up to 5x GPU speedup.
#
#
# | Format                                                                     | `format=`          | Model                     |
# |----------------------------------------------------------------------------|--------------------|---------------------------|
# | [PyTorch](https://pytorch.org/)                                            | -                  | `yolov8n.pt`              |
# | [TorchScript](https://pytorch.org/docs/stable/jit.html)                    | `torchscript`      | `yolov8n.torchscript`     |
# | [ONNX](https://onnx.ai/)                                                   | `onnx`             | `yolov8n.onnx`            |
# | [OpenVINO](https://docs.openvino.ai/latest/index.html)                     | `openvino`         | `yolov8n_openvino_model/` |
# | [TensorRT](https://developer.nvidia.com/tensorrt)                          | `engine`           | `yolov8n.engine`          |
# | [CoreML](https://github.com/apple/coremltools)                             | `coreml`           | `yolov8n.mlmodel`         |
# | [TensorFlow SavedModel](https://www.tensorflow.org/guide/saved_model)      | `saved_model`      | `yolov8n_saved_model/`    |
# | [TensorFlow GraphDef](https://www.tensorflow.org/api_docs/python/tf/Graph) | `pb`               | `yolov8n.pb`              |
# | [TensorFlow Lite](https://www.tensorflow.org/lite)                         | `tflite`           | `yolov8n.tflite`          |
# | [TensorFlow Edge TPU](https://coral.ai/docs/edgetpu/models-intro/)         | `edgetpu`          | `yolov8n_edgetpu.tflite`  |
# | [TensorFlow.js](https://www.tensorflow.org/js)                             | `tfjs`             | `yolov8n_web_model/`      |
# | [PaddlePaddle](https://github.com/PaddlePaddle)                            | `paddle`           | `yolov8n_paddle_model/`   |

# %%
# !yolo export model={HOME}/runs/classify/train/weights/best.pt format=onnx

# %% [markdown]
# ### Download Model

# %%
from google.colab import files
files.download('/content/runs/classify/train/weights/best.onnx')
